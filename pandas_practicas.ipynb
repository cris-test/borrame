# %%
import pandas as pd
# import fastparquet

# %%
tips = pd.read_csv('https://raw.githubusercontent.com/pandas-dev/pandas/refs/heads/main/pandas/tests/io/data/csv/tips.csv')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.to_parquet('tips.parquet')  # instalar fastparquet antes!!
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 tips.to_parquet('tips.parquet')
#
# File c:\Users\Cristian\Projects\borrame\.venv\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File c:\Users\Cristian\Projects\borrame\.venv\Lib\site-packages\pandas\core\frame.py:3113, in DataFrame.to_parquet(self, path, engine, compression, index, partition_cols, storage_options, **kwargs)
#    3032 """
#    3033 Write a DataFrame to the binary parquet format.
#    3034
#    (...)
# ...

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
tips.sample(10)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 24        19.82  3.18    Male     No   Sat  Dinner     2
# 190       15.69  1.50    Male    Yes   Sun  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 128       11.38  2.00  Female     No  Thur   Lunch     2
# 118       12.43  1.80  Female     No  Thur   Lunch     2
# 220       12.16  2.20    Male    Yes   Fri   Lunch     2
# 146       18.64  1.36  Female     No  Thur   Lunch     3
# 69        15.01  2.09    Male    Yes   Sat  Dinner     2
# 96        27.28  4.00    Male    Yes   Fri  Dinner     2
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2

# %%
tips.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
# loc iloc

tips.loc[2:5]  # SELECT * FROM tips WHERE id BETWEEN 2 AND 5
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4

# %%
tips.loc[[2,5,10]]
# Out:
#     total_bill   tip   sex smoker  day    time  size
# 2        21.01  3.50  Male     No  Sun  Dinner     3
# 5        25.29  4.71  Male     No  Sun  Dinner     4
# 10       10.27  1.71  Male     No  Sun  Dinner     2

# %%
tips.loc[2:5, 'smoker']
# Out:
# 2    No
# 3    No
# 4    No
# 5    No
# Name: smoker, dtype: object

# %%
tips.loc[1:4, ['smoker', 'day']]
# Out:
#   smoker  day
# 1     No  Sun
# 2     No  Sun
# 3     No  Sun
# 4     No  Sun

# %%
tips.iloc[1:4, [0,2]] # I’m here to help you with your homework
# Out:
#    total_bill   sex
# 1       10.34  Male
# 2       21.01  Male
# 3       23.68  Male

# %%
tips.loc[:,'smoker']
# Out:
# 0       No
# 1       No
# 2       No
# 3       No
# 4       No
#       ...
# 239     No
# 240    Yes
# 241    Yes
# 242     No
# 243     No
# Name: smoker, Length: 244, dtype: object

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.loc[2:5, 'total_bill'] = 0
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2          0.00  3.50    Male     No   Sun  Dinner     3
# 3          0.00  3.31    Male     No   Sun  Dinner     2
# 4          0.00  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips['sex']
# Out:
# 0      Female
# 1        Male
# 2        Male
# 3        Male
# 4      Female
#         ...
# 239      Male
# 240    Female
# 241      Male
# 242      Male
# 243    Female
# Name: sex, Length: 244, dtype: object

# %%
tips.sort_values('total_bill', ascending=False)
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3
# 212       48.33   9.00    Male     No   Sat  Dinner     4
# 59        48.27   6.73    Male     No   Sat  Dinner     4
# 156       48.17   5.00    Male     No   Sun  Dinner     6
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3
# ..          ...    ...     ...    ...   ...     ...   ...
# 149        7.51   2.00    Male     No  Thur   Lunch     2
# 111        7.25   1.00  Female     No   Sat  Dinner     1
# 172        7.25   5.15    Male    Yes   Sun  Dinner     2
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1
#
# [244 rows x 7 columns]

# %%
tips.loc[tips['size'] > 4]
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 125       29.80  4.20  Female     No  Thur   Lunch     6
# 141       34.30  6.70    Male     No  Thur   Lunch     6
# 142       41.19  5.00    Male     No  Thur   Lunch     5
# 143       27.05  5.00  Female     No  Thur   Lunch     6
# 155       29.85  5.14  Female     No   Sun  Dinner     5
# 156       48.17  5.00    Male     No   Sun  Dinner     6
# 185       20.69  5.00    Male     No   Sun  Dinner     5
# 187       30.46  2.00    Male    Yes   Sun  Dinner     5
# 216       28.15  3.00    Male    Yes   Sat  Dinner     5

# %%
tips[tips['sex'] == 'Male'][['total_bill', 'tip']]
# Out:
#      total_bill   tip
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 5         25.29  4.71
# 6          8.77  2.00
# ..          ...   ...
# 236       12.60  1.00
# 237       32.83  1.17
# 239       29.03  5.92
# 241       22.67  2.00
# 242       17.82  1.75
#
# [157 rows x 2 columns]

# %%
tips.query('day == "Sun" and size > 3')
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 4         24.59  3.61  Female     No  Sun  Dinner     4
# 5         25.29  4.71    Male     No  Sun  Dinner     4
# 7         26.88  3.12    Male     No  Sun  Dinner     4
# 11        35.26  5.00  Female     No  Sun  Dinner     4
# 13        18.43  3.00    Male     No  Sun  Dinner     4
# 44        30.40  5.60    Male     No  Sun  Dinner     4
# 47        32.40  6.00    Male     No  Sun  Dinner     4
# 52        34.81  5.20  Female     No  Sun  Dinner     4
# 54        25.56  4.34    Male     No  Sun  Dinner     4
# 116       29.93  5.07    Male     No  Sun  Dinner     4
# 153       24.55  2.00    Male     No  Sun  Dinner     4
# 154       19.77  2.00    Male     No  Sun  Dinner     4
# 155       29.85  5.14  Female     No  Sun  Dinner     5
# 156       48.17  5.00    Male     No  Sun  Dinner     6
# 157       25.00  3.75  Female     No  Sun  Dinner     4
# 159       16.49  2.00    Male     No  Sun  Dinner     4
# ...
